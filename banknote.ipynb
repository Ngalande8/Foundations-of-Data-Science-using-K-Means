# %%
import pandas as pd 

data = pd.read_csv('bank_notes.csv')

# %%
V1 = data['V1']
V2 = data['V2']

# %%
all_mean = data.mean()
all_mean
# Out:
# V1    0.433735
# V2    1.922353
# dtype: float64

# %%
all_std = data.std()
all_std
# Out:
# V1    2.842763
# V2    5.869047
# dtype: float64

# %%
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.scatter(V1, V2)

# %%
from sklearn.cluster import KMeans

combined_features = np.column_stack((V1, V2))


km_res = KMeans(n_clusters=2).fit(combined_features)

clusters = km_res.cluster_centers_

plt.scatter(V1, V2)
plt.scatter(clusters [:,0], clusters[:,1], s=1000)
