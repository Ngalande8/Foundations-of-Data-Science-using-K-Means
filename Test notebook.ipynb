# %%
print("Hello data science")
# Out:
# Hello data science

# %%
print("Hello again data science")
# Out:
# Hello again data science

# %% [markdown]
# # This is a title
# ## This is a subtitle
# * Bullet 1
# * Bullet 3

# %%
variable = input("Enter word")
print (variable)

# %%
age = 40

age = 50

age = age + 10

print(age)
# Out:
# 60

# %%
#Lists
ages = [40, 26, 27, 100, 67,57, 60]


#Sum ages

summed_ages = sum(ages)

#Mean of ages

mean_age = summed_ages / len(ages)

print(mean_age)
# Out:
# 53.857142857142854

# %%
#Better Lists: NumPy
import numpy as np

ages = np.array(ages)


print(ages.mean())
print(ages.max())
print(ages.min())
print(ages.std())
# Out:
# 53.857142857142854
# 100
# 26
# 24.02039949369566

# %%
import matplotlib.pyplot as plt
 
 
xs = [10, 100, 25, 67, 74]
ys = [125, 26, 66, 1, 10]


plt.scatter(xs, ys)

# %%
xs = [12, 35, 67] 
ys = [55, 86, 109] 
plt.scatter(xs,ys)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xs = [10, 100, 25, 67, 74]
ys = [125, 26, 66, 1, 10]


xys = [[10, 125], [100, 26], [25, 66], [67,1], [74,10]]
xys = np.array(xys)

plt.scatter(xys[: ,0], xys[: ,1])

# %%
data = [[1,2], [3,4], [5,6]]
data = np.array(data)

print ([data[0][1], data[1][1], data[2][1]])
# Out:
# [2, 4, 6]

# %%
#Mean for each column

mean = np.mean (data, 1)

print(mean)
# Out:
# [1.5 3.5 5.5]

# %%
mean = np.mean (xys, 0)

plt.scatter(xys[:,0], xys[:,1])
plt.scatter(mean[0], mean[1])

np.linalg.no

# %%
import matplotlib.patches as patches
std_dev = np.std(xys, 0)

ellipse = patches.Ellipse([mean[0], mean[1]], std_dev[0]*2, std_dev[1]*2, alpha=0.25 )

fig, graph = plt.subplots()

graph.scatter(xys[:,0], xys[:,1])
graph.scatter(mean[0], mean[1])
graph.add_patch(ellipse)

# %%
np.linalg.norm(xys[1]-mean)
# Out:
# 48.89989775040434

# %%
min = np.min(xys, 0)
max = np.max(xys, 0)

normed_x = (xys - min) / (max-min)

print(normed_x)
# Out:
# [[0.         1.        ]
#  [1.         0.2016129 ]
#  [0.16666667 0.52419355]
#  [0.63333333 0.        ]
#  [0.71111111 0.07258065]]

# %%
import matplotlib.patches as patches

mean = np.mean(normed_x, 0)
std_dev = np.std(normed_x, 0)

ellipse = patches.Ellipse([mean[0], mean[1]], std_dev[0]*2, std_dev[1]*2, alpha=0.25 )

fig, graph = plt.subplots()

graph.scatter(normed_x[:,0], normed_x[:,1])
graph.scatter(mean[0], mean[1])
graph.add_patch(ellipse)

# %%
data = [[1,2], [3,4], [5,6]]
data = np.array(data)

print([data[0][1], data[1][1], data[2][1]])
# Out:
# [2, 4, 6]
